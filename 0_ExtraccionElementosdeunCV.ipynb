# %% [markdown]
# # Vertex LLM SDK samples

# %% [markdown]
# # Ejemplo Inicial

# %% [markdown]
# # Installing the package

# %%
from google.colab import auth as google_auth
google_auth.authenticate_user()

# %%
# !gsutil cp gs://vertex_sdk_llm_private_releases/SDK/google_cloud_aiplatform-1.26.dev20230526+language.models-py2.py3-none-any.whl .
# !pip install google_cloud_aiplatform-1.26.dev20230526+language.models-py2.py3-none-any.whl "shapely<2.0"

# %% [markdown]
# #### ! ^^^^ Do not forget to click the "Restart runtime" button above.

# %% [markdown]
# # Authenticating

# %%
from google.colab import auth as google_auth
google_auth.authenticate_user()

# %%
PROJECT_ID = "cloud-llm-preview1"  # @param {type:"string"}
LOCATION = "us-central1"  # @param {type:"string"}

# %%
import vertexai
from vertexai.preview.language_models import TextGenerationModel, ChatModel

vertexai.init(project=PROJECT_ID, location=LOCATION)

# %% [markdown]
# # Prediction

# %%
from vertexai.preview.language_models import TextGenerationModel

model = TextGenerationModel.from_pretrained("google/text-bison@001")

print(model.predict(
'''

    Tu respuesta debe basarse de la siguiente información:

"
Stefanni Cavaletto
Resume
Focused on finding solutions with an analytical background for
business actions. Proficiency in designing collaborative strategies
with multidisciplinary teams. Creative and efficient achieving the
goals of the proposed challenges.
Education
2021 MSc Artificial Intelligence, Universidad Adolfo Ibanez, Santiago, Chile.
2016 Post-title Business Intelligence, Universidad de Chile, Santiago, Chile.
2015 Math Engineer, Universidad de Santiago de Chile, Santiago, Chile.
Specialty in Optimization
2014 BS Mathematical Science, Universidad de Satiago de Chile, Santiago, Chile.
Certifications
Google Google Certified: Professional Machine Learning Engineer, 2022.
Google Google Certified: Cloud Digital Leader, 2022.
Microsoft Microsoft Certified: Azure AI Fundamentals, 2021.
Microsoft Microsoft Certified: Azure Data Fundamentals, 2021.
Microsoft Microsoft Certified: Azure Data Scientist Associate, 2020.
Microsoft Microsoft Certified: Azure Fundamentals, 2020.
OpenHack Microsoft OpenHack: AI-Powered Knowledge Mining, 2020.
OpenHack Microsoft OpenHack: Modern Data Warehousing, 2020.
Microsoft Microsoft Certified: Azure AI Engineer Associate, 2019.
Microsoft Microsoft Certified: Azure Data Engineer Associate, 2019.
Experience
Vocational
2022 - Actual Customer Engineer (Machine Learning & Artificial Intelligence), Google Cloud,
Santiago, Chile.
As as CE, she is working with technical sales teams as a machine learning subject matter expert
to differentiate Google Cloud to our customers. She help prospective customers and partners
understand the power of Google Cloud. She provide in-deph machine learning expertise to support
the technical relationship with Google’s customers, including product and solution briefings, proof￾of-concept work (PoC), and partner directly with product management to prioritize solutions
impacting customer adoption to GCP.
2019 - 2022 Cloud Solution Architect (Azure Data and AI), Microsoft Chile, Santiago, Chile.
The Cloud Solution Architect must have current and deep experience with implementation of cloud
technologies and Data & AI. The Cloud Solution Architect applies advanced analysis skills and
experience in principals of architecture to define appropriate customer solutions and own the Data
Platform & Advanced Analytics technical customer engagements.
2022 - Actual Teacher Deep Learning, Universidad Andrés Bello, Santiago, Chile.
2021 - Actual Teacher Artificial Intelligence, Universidad Andrés Bello, Santiago, Chile.
2018 - 2019 Data Scientist Corp and Scrum Master, Sodimac S.A, Santiago, Chile.
Data Scientist main function was to research and implement machine learning models at the
regional level (Chile, Peru, Argentina, Uruguay, Colombia, Mexico and Brazil)
Scrum Master main function was was implementing the agile methodology in your work team, in
addition i was coordinating and facilitating the field of action to be able to achieve the goals and
deadlines.
2017 - 2019 Data Scientist consultant, Freelance, Santiago, Chile.
Main projects:
{ CORFO Project in Hospital, was developing a model to predict whether patients who had
treatment related to advanced diabetes and breast cancer could improve based on historical data
from other patients who also participated in the study.(2019)
{ Churn Analysis for "Consorcio Seguros" (2017)
{ Hot spots (sales) model for the company Alicorp Peru (2017).
{ Design of segmentation models for COPPEL Mexico.
2016 - 2018 Data Scientist, EY-Metricarts, Santiago, Chile.
The main objective of the position is the study and analysis of efficient solutions for different
situations that fit the business. Among these solutions is the design or selection of predictive or
segmentation models. Knowledge of tools that are currently being used was essential (for example,
Azure Machine Learning Studio is used for studying machine learning), in addition to possessing
theoretical knowledge in Statistics and Probabilities.
2015 - 2016 Functional Campaign Analyst, Cencosud S.A., Santiago, Chile.
Analysis and evaluation of campaigns design for mass consumption, generated with analytical
support and data mining. Cencosud analysts have great responsibility and it is key to have good
criterion to achieve efficient campaigns and with great incremental benefit.
2014 - 2015 Product Manager Loyalty and Training, Claro Chile S.A., Santiago, Chile.
The main objective is to design and manage campaigns to avoid the flight of business customers to
the competition, i was using data mining and business intelligence.
2013 - 2014 Business Analyst, Antica, Santiago, Chile.
The role consisted of performing one-dimensional and multivariate analysis in the business intelligence
domain, using statistical programs such as R for database management, as well as Queries in SQL,
scripting using PERL or PHP for more in-depth queries and even knowing how to use commands in
AWK.
2013 Professional Internship in Business Intelligence, Claro Chile S.A. Empresas,
Rinconada – El Salto 100, Santiago.
Collaborate in the creation of predictive models of Customer Churn called Predictive Churn Scoring
Model, based on multivariate logistic regression. SPSS statistical software was used.
2013 2nd
semester
Teacher’s assistant in Calculus 2 and Algebra 2, Universidad Diego Portales,
Santiago, Chile.
Helping the teacher taking assessments, to teach exercises classes and to complement with guides
to the students of Logistics Engineering major.
2012 Teacher’s assistant in Calculus 1, Universidad de Santiago de Chile, Santiago, Chile.
Academic assistant for Common Engineering Plan major.
2011 2nd
semestre
Teacher’s assistant for Linear Algebra, Universidad de Santiago de Chile, Santiago,
Chile.
Academic assistant for Common Engineering Plan major.
2010 – 2011
(1st semester)
Teacher’s assistant for Differential and Integral Calculus, Universidad de Santiago
de Chile, Santiago, Chile.
Academic assistant for Business majors in the Management and Economy Faculty.
Awards
2021 Tech Talent Award Winner on Micrososft Latam
Computer Skills
Analytics and
AI
Azure Machine Learning,Azure Databricks,SPSS Modeler,R,Python, Azure Synapse An￾alytics,Power BI, Azure Cognitive Services (LUIS, Text Analytics, Custom Vision,QnA
Maker,etc)
Database Azure SQL Database,SQL Server,Postgresql,Azure Time Serie,Azure Cosmos DB
ETL/ELT SQL server Integration Services,Azure Databricks,Azure Data Factory
Others Azure DevOps,LATEX,Microsoft Office Excel,PHP,AMPL,Matlab
Training and Other Certifications
Microsoft Accessibility in Action, 2020.
Microsoft Microsoft Global Challenger, 2020.
Databricks Training: ADB Core Technical Virtual, 2020.
BeSmart Data Manipulation with IBM SPSS Modeler, 2016.
BeSmart Modeling with IBM SPSS Modeler, 2016.
Volunteer experience
2021 - 2022 Fundación Ciencias de la Documentación, Mujeres Lideres de las Americas, VIP mem￾ber and part of the Advisory Council.
2019 - 2022 Meetup Analytics and Python, Organizing team.
2020 - 2021 Microsoft - "Club Arquitectos CL", Leader Organizer.
2019 Saturdays.ai Chile, Project Mentor.
2019 Laboratoria, Student Mentor.
2017 - 2019 R-Ladies, Collaborator.

Las siemprevivas 9396 – La Florida, Santiago, Chile
H (9) 65 929 837 • B stefanni.cavaletto@gmail.com

"
Organiza toda la información relacionada a experiencia laboral   en un tabla de la siguiente forma tabla:

"periodo;tipo de rol; nombre rol; skill principal del rol; nombre empresa; rubro empresa"

en una tabla abajo de esta, agrega un breve resumen que tenga el siguiente formato tabla:

"Nombre candidato; datos de contacto telefono; datos de contacto email; tres principales habilidades; posibles cargos recomendados "



    ''',
        temperature=.2,
        max_output_tokens=256,
        top_k=40,
        top_p=.95,
))
# Out:
# **Experience**
#
# | Period | Role | Skill | Company | Industry |
# |---|---|---|---|---|
# | 2022 - Present | Customer Engineer (Machine Learning & Artificial Intelligence) | Machine Learning | Google Cloud | Cloud |
# | 2019 - 2022 | Cloud Solution Architect (Azure Data and AI) | Azure Data & AI | Microsoft Chile | Cloud |
# | 2022 - Present | Teacher Deep Learning | Deep Learning | Universidad Andrés Bello | Education |
# | 2021 - Present | Teacher Artificial Intelligence | Artificial Intelligence | Universidad Andrés Bello | Education |
# | 2018 - 2019 | Data Scientist Corp and Scrum Master | Machine Learning | Sodimac S.A | Retail |
# | 2017 - 2019 | Data Scientist consultant | Data Science | Freelance | Consulting |
# | 2016 - 2018 | Data Scientist | Data Science | EY-Metricarts | Consulting |
# | 2015 - 2016 | Functional Campaign Analyst | Business Intelligence | Cencosud S.A | Retail |
# | 2014 -
