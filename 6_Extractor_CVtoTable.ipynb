# %%
############################################################################
# Copyright 2023 Google LLC
#
# Licensed under the Apache License, Version 2.0 (the "License");
# you may not use this file except in compliance with the License.
# You may obtain a copy of the License at
#
#    https://www.apache.org/licenses/LICENSE-2.0
#
# Unless required by applicable law or agreed to in writing, software
# distributed under the License is distributed on an "AS IS" BASIS,
# WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# See the License for the specific language governing permissions and
# limitations under the License.
############################################################################
#  DISCLAIMER
# The code shared by CEs with customers must be limited to non-production
# demo/example code or infrastructure automation scripts.
############################################################################
## Colab: @scavaletto

# %% [markdown]
# # Vertex AI SDK for Python: applied examples Entity extraction with LLM models with **text-bison model**
# <table align="left">
#   <td>
#     <a href=" ">
#       <img src="https://cloud.google.com/ml-engine/images/colab-logo-32px.png" alt="Colab logo"> Run in Colab
#     </a>
#   </td>
#   <td>
#     <a href=" ">
#       <img src="https://cloud.google.com/ml-engine/images/github-logo-32px.png" alt="GitHub logo">
#       View on GitHub
#     </a>
#   </td>
#   <td>
# <a href=" " target='_blank'>
#       <img src="https://lh3.googleusercontent.com/UiNooY4LUgW_oTvpsNhPpQzsstV5W8F7rYgxgGBD85cWJoLmrOzhVs_ksK_vgx40SHs7jCqkTkCk=e14-rj-sc0xffffff-h130-w32" alt="Vertex AI logo">
#       Open in Vertex AI Workbench
#     </a>
#   </td>
# </table>

# %% [markdown]
# # Vertex LLM SDK samples

# %% [markdown]
# # Installing the package

# %%
# We have to first authenticate
from google.colab import auth as google_auth
google_auth.authenticate_user()

# %%
# !pip install google-cloud-aiplatform

# %% [markdown]
# #### ! ^^^^ Do not forget to click the "Restart runtime" button

# %% [markdown]
# # Authenticating

# %%
PROJECT_ID = "cloud-llm-preview1"  # @param {type:"string"}
LOCATION = "us-central1"  # @param {type:"string"}

# %%
import vertexai
from langchain.llms import VertexAI
vertexai.init(project=PROJECT_ID, location=LOCATION)

# %% [markdown]
# # Prediction

# %%
model = TextGenerationModel.from_pretrained("google/text-bison@001")

#Here is a fictional curriculum vitae for Stefanni CH:

print(model.predict(
'''

    Tu respuesta debe basarse de la siguiente información:

"
Personal Information

Name: Stefanni CH

Email: stefannich@email.com

LinkedIn: linkedin.net/in/stefannich?20111

Summary

Stefanni CH is a highly motivated and experienced professional with a proven track record of success in the technology industry. She is a skilled software engineer with a strong understanding of cloud computing and artificial intelligence. She is also a passionate advocate for social justice and has a strong commitment to giving back to her community.

Experience

Software Engineer, Google (2021-Present)

Developed and maintained software for Google's cloud computing platform.

Worked on a team to develop a new artificial intelligence algorithm.

Presented research at a major academic conference.

Software Engineer, Microsoft (2019-2021)

Developed and maintained software for Microsoft's cloud computing platform.

Worked on a team to develop a new machine learning algorithm.

Received a patent for a new software invention.

Research Assistant, University of Chile (2017-2019)

Worked on a research project in the field of artificial intelligence.

Published a paper in a top academic journal.

Received a fellowship to attend a prestigious summer school.

Education

Master of Science in Computer Science, University of Chile (2019)
Bachelor of Science in Computer Science, Universidad de Santiago de Chile (2017)
Certifications

Certified Cloud Architect - AWS
Certified Azure Developer
Certified Google Cloud Platform Architect
Volunteer Work

Volunteered at a local soup kitchen.
Mentored young people interested in pursuing a career in technology.
Donated money to a charity that supports education in developing countries.
Skills

Programming languages: Java, Python, C++, C#
Cloud computing platforms: AWS, Azure, Google Cloud Platform
Artificial intelligence: Machine learning, natural language processing, computer vision
Software engineering: Agile development, unit testing, continuous integration
Data analysis: SQL, Tableau, Power BI
Communication: Public speaking, writing, interpersonal skills
Awards and Honors

Dean's List, University of Chile
President's List, Universidad de Santiago de Chile
Google Anita Borg Memorial Scholarship
Microsoft Research Fellowship
Interests

Artificial intelligence
Cloud computing
Social justice
Travel
Reading
Hiking

"
Organiza toda la información relacionada a experiencia laboral   en un tabla que contenta toda la información de la siguiente forma tabla:

"periodo;tipo de rol; nombre rol; skill principal del rol; nombre empresa; rubro empresa"


    ''',
        temperature=.2,
        max_output_tokens=1024,
        top_k=40,
        top_p=.95,
))

#en una tabla abajo de esta, agrega un breve resumen que tenga el siguiente formato tabla:
#"Nombre candidato; datos de contacto telefono; datos de contacto email; principales habilidades; posibles cargos recomendados "
# Out:
# | Period | Role Type | Role | Main Skill | Company | Industry |
# |---|---|---|---|---|---|
# | 2022 - Actual | Customer Engineer | Machine Learning & Artificial Intelligence | Machine Learning | Google Cloud | Cloud |
# | 2019 - 2022 | Cloud Solution Architect | Azure Data and AI | Data & AI | Microsoft Chile | Cloud |
# | 2022 - Actual | Teacher | Deep Learning | Deep Learning | Universidad Andrés Bello | Education |
# | 2021 - Actual | Teacher | Artificial Intelligence | Artificial Intelligence | Universidad Andrés Bello | Education |
# | 2018 - 2019 | Data Scientist Corp and Scrum Master | Data Scientist | Machine Learning | Sodimac S.A | Retail |
# | 2017 - 2019 | Data Scientist consultant | Freelance | Machine Learning | Various | Various |
# | 2016 - 2018 | Data Scientist | EY-Metricarts | Machine Learning | EY-Metricarts | Consulting |
# | 2015 - 2016 | Functional Campaign Analyst | Cencosud S.A. | Data Mining | Cencosud S.A. | Retail |
# ...
